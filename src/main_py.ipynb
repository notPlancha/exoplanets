# %%
import kagglehub
import pandas as pd

path = kagglehub.dataset_download("eduardowoj/exoplanets-database") + "/kepler.csv"
df = pd.read_csv(path)
# Out:
#                       # name planet_status    mass  mass_error_min  \
# 0      OGLE-2016-BLG-1469L b     Confirmed  13.600           3.000
# 1                   11 Com b     Confirmed  19.400           1.500
# 2                   11 Oph b     Confirmed  21.000           3.000
# 3                   11 UMi b     Confirmed  10.500           2.470
# 4                   14 And b     Confirmed   5.330           0.570
# ...                      ...           ...     ...             ...
# 3727               tau Gem b     Confirmed  20.600             NaN
# 3728               ups And b     Confirmed   0.620           0.090
# 3729               ups And c     Confirmed   9.100           2.900
# 3730               ups And d     Confirmed  23.580           2.295
# 3731               ups And e     Confirmed   1.059           0.028
#
#       mass_error_max  mass_sini  mass_sini_error_min  mass_sini_error_max  \
# 0              3.000        NaN                  NaN                  NaN
# ...
