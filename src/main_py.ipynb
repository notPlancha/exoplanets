# %%
import pandas as pd
from astropy.io.votable import parse as vot
from pyprojroot.here import here

df = pd.read_csv(here("data/exoplanet_catalog_080325.csv"))
df
# Out:
#                    name planet_status    mass  mass_error_min  mass_error_max  \
# 0             109 Psc b     Confirmed   5.743         0.28900         1.01100
# 1             112 Psc b     Confirmed     NaN         0.00500         0.00400
# 2             112 Psc c     Confirmed   9.866         1.78100         3.19000
# 3             11 Com Ab     Confirmed     NaN         1.53491         1.53491
# 4              11 UMi b     Confirmed     NaN         1.10000         1.10000
# ...                 ...           ...     ...             ...             ...
# 7413  ZTF J1406+1222 Ab     Confirmed  50.000             NaN             NaN
# 7414     ZTF J1622+47 b     Confirmed  61.000        19.00000        19.00000
# 7415     ZTF J1637+49 b     Confirmed  23.000         8.00000         8.00000
# 7416   ZTF J1828+2308 b     Confirmed  19.500         0.80000         0.80000
# 7417     ZTF J2252-05 b     Confirmed  26.000         8.00000         8.00000
#
# ...
